# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd "/gdrive/MyDrive/Colab Notebooks/[HCMUE - TextMining] Summarization/"
# Out:
# Mounted at /gdrive
# /gdrive/MyDrive/Colab Notebooks/[HCMUE - TextMining] Summarization

# %%
# !pip uninstall numpy -y
# !pip uninstall pandas -y
# !pip uninstall tqdm -y
# !pip uninstall tensorflow -y

# !pip install numpy==1.19.2
# !pip install pandas==1.1.3
# !pip install tqdm==4.54.0
# !pip install tensorflow==2.1.0
# Out:
# Uninstalling numpy-1.18.5:
#   Successfully uninstalled numpy-1.18.5
# Uninstalling pandas-1.1.4:
#   Successfully uninstalled pandas-1.1.4
# Uninstalling tqdm-4.41.1:
#   Successfully uninstalled tqdm-4.41.1
# Uninstalling tensorflow-2.3.0:
#   Successfully uninstalled tensorflow-2.3.0
# ...
#      |████████████████████████████████| 14.5MB 338kB/s
# ERROR: xarray 0.15.1 requires pandas>=0.25, which is not installed.
# ERROR: torchtext 0.3.1 requires tqdm, which is not installed.
# ERROR: thinc 7.4.0 requires tqdm<5.0.0,>=4.10.0, which is not installed.
# ERROR: tensorflow-datasets 4.0.1 requires tqdm, which is not installed.
# ERROR: statsmodels 0.10.2 requires pandas>=0.19, which is not installed.
# ERROR: spacy 2.2.4 requires tqdm<5.0.0,>=4.38.0, which is not installed.
# ERROR: sklearn-pandas 1.8.0 requires pandas>=0.11.0, which is not installed.
# ERROR: seaborn 0.11.0 requires pandas>=0.23, which is not installed.
# ERROR: pymc3 3.7 requires pandas>=0.18.0, which is not installed.
# ...

# %%
# !python src/data/make_dataset.py --input_path data/raw/ --output_path data/processed --maxlen_sentence 500 --maxlen_word 3000
# Out:
# Read data from txt...
# Read data from txt...
# Processing...
# Clean text...
# Clean text...
#
# Save processed data...

# %%
# !python src/features/convert_data.py --input_path data/processed --output_path data/interim --save_tokenizer models/tokenizer.json
# Out:
# 2020-12-04 04:23:38.817560: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2020-12-04 04:23:38.818987: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2020-12-04 04:23:38.819025: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Read processed data...
# Load tokenizer from json...
# Transform tokenizer...
# 100% 3/3 [00:00<00:00, 1174.22it/s]
# Save tokenized data...

# %%
# !python src/models/train_model.py --train_folder data/interim --valid_folder data/interim --epochs 1 --path_tokenizer models/tokenizer.json --output_model models/model_save.h5
# Out:
# 2020-12-04 04:23:43.677458: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2020-12-04 04:23:43.677575: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2020-12-04 04:23:43.677596: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Train model file...
# Tensorflow Version: 2.1.0
# Not connected to a TPU runtime!
# Load tokenizer from json...
# Read tokenized data...
# ...

# %%
# !python src/models/predict_model.py --input_path data/raw/demo_predict.txt --output_path abc --tokenizer_path models/tokenizer.json --model_path models/model_trained.h5
# Out:
# 2020-12-04 04:24:06.718780: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2020-12-04 04:24:06.718906: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2020-12-04 04:24:06.718927: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Read data from txt...
# Clean text...
# Processing...
# Load tokenizer from json...
# Transform tokenizer...
# ...
